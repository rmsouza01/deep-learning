# %% [markdown]
# <a href="https://colab.research.google.com/github/aarontjoseph94/ENEL645-Assignments/blob/dev_bright/assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 02 - CIFAR10 Image Classification
#
# In this assignment your team will design a fully connected neural network and a convolutional neural network (CNN) models for classifiying the CIFAR10 image dataset. The deliverables for the assignment are:
#
# 1. This jupyter-notebook completed with your solution. I expect you to try different configurations (models, train/validtion split, etc.), but for your submission, leave just the best fully connected and the best CNN models.
#     - Name the notebook as enel645_assignment02_team_(team number).ipynb
# 2. The weights of your best fully connected neural network model and your best CNN model
#     - Name the weights files as team_(team number)_FCN.h5 (fully connected model) and team_(team number)_FCN.h5 (CNN model)
#
# Submit the three files (notebook + models' weights) to your dropbox in the course D2L page.
#
# We will be using the CIFAR10 dataset. The dataset alerady comes with a test set and you shouldn't change it. It is up to you to determine how to split your development set into training and validation sets. Use variable names consistent with the variables pre-filled in this document.
#
#
# You are free to add extra cells of text and code to this notebook.
#
# At the end of the notebook, please include a short description of what each team member did in the assignment. Also include the consensus score between 0 and 3 to each team member. This score will be used to adjust the final
# grade of each student. Students developing the project individually do not need this description and score.
#
# You are being assessed based on:
#
# 1. Code execution - 20%
# 2. Clarity of the code (e.g., easy to follow, has pertinent comments, etc.) - 20%
# 3. Proper usage of the techniques seen in class - 30%
# 4. Accuracy of the models  - 30%

# %%
import matplotlib.pylab as plt
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## 1. Load your data

# %%
(X_dev, Y_dev), (X_test, Y_test) = tf.keras.datasets.cifar10.load_data()

print(X_dev.shape)
print(X_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## 2. Explore your data

# %%
# Checking the shape of the dev and test sets
print(f"The shape of the Training and validation dataset is {X_dev.shape}")
print(f"The shape of the Training and validation labels is {Y_dev.shape}")
print(f"The shape of the test dataset is {X_test.shape}")
print(f"The shape of the test labels is {Y_test.shape}")
# Out:
# The shape of the Training and validation dataset is (50000, 32, 32, 3)
# The shape of the Training and validation labels is (50000, 1)
# The shape of the test dataset is (10000, 32, 32, 3)
# The shape of the test labels is (10000, 1)

# %%
#Checking the number of classes of the target set
print(f"The number of classes is {np.unique(Y_dev).size}")
# Out:
# The number of classes is 10

# %%
#Displaying some samples from the dataset
sample_indexes = np.random.choice(np.arange(X_dev.shape[0], dtype = int),size = 30, replace = False)
plt.figure(figsize = (24,18))
for (ii,jj) in enumerate(sample_indexes):
    plt.subplot(5,6,ii+1)
    plt.imshow(X_dev[jj], cmap = "gray")
    plt.title("Label: %d" %Y_dev[jj])
plt.show()

# %%
#Spliting the dev dataset into training and validation sets
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

#Shuffling the dataset
X_dev, Y_dev = shuffle(X_dev, Y_dev)

#Splitting the dataset into train and validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_dev, Y_dev, test_size = 0.25, random_state = 1)

print("\nTrain set")
print("Images: ",X_train.shape)
print("Labels shape: ",Y_train.shape)
print("\nValidation set")
print("Images: ",X_val.shape)
print("Labels shape: ",Y_val.shape)
# Out:
# Train set
# Images:  (37500, 32, 32, 3)
# Labels shape:  (37500, 1)
#
# Validation set
# Images:  (12500, 32, 32, 3)
# Labels shape:  (12500, 1)

# %%
print(X_train.min(),X_train.max(),X_train.mean(),X_train.std())
print(X_val.min(),X_val.max(),X_val.mean(),X_val.std())
# Out:
# 0 255 120.72528926215277 64.15304491527381
# 0 255 120.65439270833333 64.14113860777672

# %% [markdown]
# ## 3. Represent your labels using one hot encoding

# %%
Y_train_oh = tf.keras.utils.to_categorical(Y_train)
Y_val_oh = tf.keras.utils.to_categorical(Y_val)
Y_test_oh = tf.keras.utils.to_categorical(Y_test)

# %% [markdown]
# ## 4. Data scaling and Data augmentation

# %%
norm_type = 0 # 0 -> min-max; 1-> standardization

if norm_type == 0:
    X_train = X_train/255
    X_val = X_val/255
    X_test = X_test/255
elif norm_type == 1:
    train_mean, train_std = X_train.mean(),X_train.std() 
    X_train = (X_train - train_mean)/train_std
    X_val = (X_val - train_mean)/train_std
    X_test = (X_test - train_mean)/train_std
else:
    pass

# %%
train_datagen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, 
                             shear_range=0.15, zoom_range=0.1, channel_shift_range=10, 
                             horizontal_flip=True, vertical_flip=True)

val_datagen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, 
                             shear_range=0.15, zoom_range=0.1, channel_shift_range=10, 
                             horizontal_flip=True, vertical_flip=True)

train_datagen.fit(X_train)
val_datagen.fit(X_val)

train_dataflow = train_datagen.flow(X_train,Y_train_oh,batch_size = 32)
val_dataflow = val_datagen.flow(X_val,Y_val_oh,batch_size = 32)

# %% [markdown]
# ## Fully Connected Model
#
# ## 5. Define your  model, cost function, optimizer, learning rate

# %%
# Define your model here. Include accuracy in the metrics list when you compile it
# Experiment with different network architectures, learnig rates, dropout, etc.
def my_model_fully_connected(ishape=(32, 32, 3), k= 10, lr=1e-4, drop=0.2):
  model_input = tf.keras.layers.Input(shape=ishape)
  model_input_flattened = tf.keras.layers.Flatten()(model_input)
  model_layer1 = tf.keras.layers.Dense(256, activation="relu")(model_input_flattened)
  model_drop = tf.keras.layers.Dropout(rate=drop)(model_layer1)
  output = tf.keras.layers.Dense(k, activation = 'softmax')(model_drop)
  model = tf.keras.models.Model(inputs=model_input, outputs= output)
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='categorical_crossentropy', metrics = ["accuracy"])
  return model

# %%
model = my_model_fully_connected()
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 789,258
# Trainable params: 789,258
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6. Define your callbacks (save your model, patience, etc.)

# %%
model_name_fcn = "team_(team number)_FCN.h5"

# define your callbacks
# remember that you need to save the weights of your best model!

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 20)

monitor = tf.keras.callbacks.ModelCheckpoint(model_name_fcn, monitor='val_loss',\
                                             verbose=0,save_best_only=True,\
                                             save_weights_only=True,\
                                             mode='min')
# Learning rate schedule
def scheduler(epoch, lr):
    if epoch%6 == 0 and epoch!= 0:
        lr = lr/2
    return lr

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose = 0)

# %% [markdown]
# ## 7. Train your model

# %%
# train your model - decide for how many epochs
model.fit(X_train, Y_train_oh, batch_size = 32, epochs = 1000, \
          verbose = 1, callbacks= [early_stop, monitor, lr_schedule], validation_data=(X_val,Y_val_oh))
# Out:
# Epoch 1/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 2.0586 - accuracy: 0.2500 - val_loss: 1.8118 - val_accuracy: 0.3583
# Epoch 2/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.8127 - accuracy: 0.3600 - val_loss: 1.7136 - val_accuracy: 0.3943
# Epoch 3/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.7361 - accuracy: 0.3866 - val_loss: 1.6870 - val_accuracy: 0.4009
# Epoch 4/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.6945 - accuracy: 0.4079 - val_loss: 1.6271 - val_accuracy: 0.4289
# Epoch 5/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.6528 - accuracy: 0.4185 - val_loss: 1.6118 - val_accuracy: 0.4385
# Epoch 6/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.6153 - accuracy: 0.4362 - val_loss: 1.5831 - val_accuracy: 0.4404
# Epoch 7/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5776 - accuracy: 0.4501 - val_loss: 1.5513 - val_accuracy: 0.4585
# Epoch 8/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5679 - accuracy: 0.4503 - val_loss: 1.5497 - val_accuracy: 0.4519
# Epoch 9/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5507 - accuracy: 0.4563 - val_loss: 1.5345 - val_accuracy: 0.4650
# Epoch 10/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5375 - accuracy: 0.4617 - val_loss: 1.5254 - val_accuracy: 0.4658
# Epoch 11/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5254 - accuracy: 0.4686 - val_loss: 1.5138 - val_accuracy: 0.4711
# Epoch 12/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.5195 - accuracy: 0.4751 - val_loss: 1.4999 - val_accuracy: 0.4731
# Epoch 13/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4885 - accuracy: 0.4792 - val_loss: 1.5001 - val_accuracy: 0.4734
# Epoch 14/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4839 - accuracy: 0.4868 - val_loss: 1.4951 - val_accuracy: 0.4753
# Epoch 15/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4833 - accuracy: 0.4860 - val_loss: 1.4856 - val_accuracy: 0.4789
# Epoch 16/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4787 - accuracy: 0.4867 - val_loss: 1.4840 - val_accuracy: 0.4814
# Epoch 17/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4729 - accuracy: 0.4895 - val_loss: 1.4799 - val_accuracy: 0.4807
# Epoch 18/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4627 - accuracy: 0.4906 - val_loss: 1.4777 - val_accuracy: 0.4826
# Epoch 19/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4452 - accuracy: 0.4957 - val_loss: 1.4698 - val_accuracy: 0.4865
# Epoch 20/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4434 - accuracy: 0.4968 - val_loss: 1.4677 - val_accuracy: 0.4866
# Epoch 21/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4430 - accuracy: 0.4992 - val_loss: 1.4659 - val_accuracy: 0.4876
# Epoch 22/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4335 - accuracy: 0.5045 - val_loss: 1.4656 - val_accuracy: 0.4866
# Epoch 23/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4475 - accuracy: 0.4963 - val_loss: 1.4646 - val_accuracy: 0.4851
# Epoch 24/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4418 - accuracy: 0.5015 - val_loss: 1.4612 - val_accuracy: 0.4866
# Epoch 25/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4378 - accuracy: 0.4995 - val_loss: 1.4584 - val_accuracy: 0.4900
# Epoch 26/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4331 - accuracy: 0.5033 - val_loss: 1.4552 - val_accuracy: 0.4894
# Epoch 27/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4218 - accuracy: 0.5098 - val_loss: 1.4546 - val_accuracy: 0.4902
# Epoch 28/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4358 - accuracy: 0.5068 - val_loss: 1.4546 - val_accuracy: 0.4908
# Epoch 29/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4215 - accuracy: 0.5123 - val_loss: 1.4538 - val_accuracy: 0.4924
# Epoch 30/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4165 - accuracy: 0.5109 - val_loss: 1.4545 - val_accuracy: 0.4948
# Epoch 31/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4186 - accuracy: 0.5097 - val_loss: 1.4523 - val_accuracy: 0.4903
# Epoch 32/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4160 - accuracy: 0.5131 - val_loss: 1.4515 - val_accuracy: 0.4912
# Epoch 33/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4158 - accuracy: 0.5147 - val_loss: 1.4516 - val_accuracy: 0.4913
# Epoch 34/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4144 - accuracy: 0.5080 - val_loss: 1.4510 - val_accuracy: 0.4913
# Epoch 35/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4171 - accuracy: 0.5098 - val_loss: 1.4511 - val_accuracy: 0.4903
# Epoch 36/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4150 - accuracy: 0.5122 - val_loss: 1.4501 - val_accuracy: 0.4931
# Epoch 37/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4170 - accuracy: 0.5101 - val_loss: 1.4491 - val_accuracy: 0.4934
# Epoch 38/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4168 - accuracy: 0.5138 - val_loss: 1.4495 - val_accuracy: 0.4927
# Epoch 39/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4132 - accuracy: 0.5110 - val_loss: 1.4491 - val_accuracy: 0.4942
# Epoch 40/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4090 - accuracy: 0.5123 - val_loss: 1.4490 - val_accuracy: 0.4942
# Epoch 41/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4145 - accuracy: 0.5119 - val_loss: 1.4487 - val_accuracy: 0.4946
# Epoch 42/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4077 - accuracy: 0.5137 - val_loss: 1.4484 - val_accuracy: 0.4929
# Epoch 43/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4270 - accuracy: 0.5052 - val_loss: 1.4482 - val_accuracy: 0.4936
# Epoch 44/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4093 - accuracy: 0.5156 - val_loss: 1.4479 - val_accuracy: 0.4926
# Epoch 45/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4016 - accuracy: 0.5182 - val_loss: 1.4480 - val_accuracy: 0.4934
# Epoch 46/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4112 - accuracy: 0.5108 - val_loss: 1.4480 - val_accuracy: 0.4936
# Epoch 47/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4146 - accuracy: 0.5122 - val_loss: 1.4480 - val_accuracy: 0.4942
# Epoch 48/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.3982 - accuracy: 0.5180 - val_loss: 1.4478 - val_accuracy: 0.4935
# Epoch 49/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.3945 - accuracy: 0.5180 - val_loss: 1.4478 - val_accuracy: 0.4932
# Epoch 50/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4097 - accuracy: 0.5081 - val_loss: 1.4477 - val_accuracy: 0.4929
# Epoch 51/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4046 - accuracy: 0.5100 - val_loss: 1.4477 - val_accuracy: 0.4932
# Epoch 52/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4088 - accuracy: 0.5128 - val_loss: 1.4475 - val_accuracy: 0.4937
# Epoch 53/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4078 - accuracy: 0.5145 - val_loss: 1.4475 - val_accuracy: 0.4936
# Epoch 54/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4068 - accuracy: 0.5134 - val_loss: 1.4475 - val_accuracy: 0.4941
# Epoch 55/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4102 - accuracy: 0.5116 - val_loss: 1.4475 - val_accuracy: 0.4940
# Epoch 56/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4056 - accuracy: 0.5119 - val_loss: 1.4475 - val_accuracy: 0.4942
# Epoch 57/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4187 - accuracy: 0.5115 - val_loss: 1.4475 - val_accuracy: 0.4939
# Epoch 58/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4100 - accuracy: 0.5113 - val_loss: 1.4474 - val_accuracy: 0.4940
# Epoch 59/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4014 - accuracy: 0.5145 - val_loss: 1.4474 - val_accuracy: 0.4939
# Epoch 60/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4066 - accuracy: 0.5130 - val_loss: 1.4473 - val_accuracy: 0.4941
# Epoch 61/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4051 - accuracy: 0.5186 - val_loss: 1.4473 - val_accuracy: 0.4938
# Epoch 62/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4073 - accuracy: 0.5124 - val_loss: 1.4473 - val_accuracy: 0.4938
# Epoch 63/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.3960 - accuracy: 0.5200 - val_loss: 1.4473 - val_accuracy: 0.4945
# Epoch 64/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4167 - accuracy: 0.5142 - val_loss: 1.4472 - val_accuracy: 0.4944
# Epoch 65/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4015 - accuracy: 0.5209 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 66/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4037 - accuracy: 0.5156 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 67/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4063 - accuracy: 0.5147 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 68/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4074 - accuracy: 0.5128 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 69/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.3978 - accuracy: 0.5220 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 70/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4119 - accuracy: 0.5091 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 71/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4147 - accuracy: 0.5140 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 72/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4130 - accuracy: 0.5168 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 73/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4058 - accuracy: 0.5106 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 74/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4080 - accuracy: 0.5126 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 75/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4085 - accuracy: 0.5138 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 76/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4123 - accuracy: 0.5107 - val_loss: 1.4472 - val_accuracy: 0.4944
# Epoch 77/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4062 - accuracy: 0.5182 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 78/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4039 - accuracy: 0.5149 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 79/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4073 - accuracy: 0.5152 - val_loss: 1.4472 - val_accuracy: 0.4945
# Epoch 80/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4154 - accuracy: 0.5140 - val_loss: 1.4472 - val_accuracy: 0.4946
# Epoch 81/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4102 - accuracy: 0.5128 - val_loss: 1.4472 - val_accuracy: 0.4944
# Epoch 82/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4200 - accuracy: 0.5105 - val_loss: 1.4472 - val_accuracy: 0.4944
# Epoch 83/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4027 - accuracy: 0.5157 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 84/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4120 - accuracy: 0.5106 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 85/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4012 - accuracy: 0.5173 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 86/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4050 - accuracy: 0.5121 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 87/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4165 - accuracy: 0.5071 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 88/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4031 - accuracy: 0.5150 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 89/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4075 - accuracy: 0.5151 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 90/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4114 - accuracy: 0.5127 - val_loss: 1.4472 - val_accuracy: 0.4943
# Epoch 91/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4087 - accuracy: 0.5166 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 92/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4090 - accuracy: 0.5153 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 93/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4096 - accuracy: 0.5102 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 94/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4103 - accuracy: 0.5113 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 95/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4113 - accuracy: 0.5145 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 96/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4023 - accuracy: 0.5224 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 97/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4045 - accuracy: 0.5129 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 98/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4119 - accuracy: 0.5130 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 99/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4084 - accuracy: 0.5159 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 100/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.3991 - accuracy: 0.5162 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 101/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4076 - accuracy: 0.5142 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 102/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4124 - accuracy: 0.5128 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 103/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4114 - accuracy: 0.5178 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 104/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4091 - accuracy: 0.5117 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 105/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4139 - accuracy: 0.5125 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 106/1000
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.4076 - accuracy: 0.5176 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 107/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4019 - accuracy: 0.5158 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 108/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4137 - accuracy: 0.5127 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 109/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4123 - accuracy: 0.5124 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 110/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4077 - accuracy: 0.5069 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 111/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4122 - accuracy: 0.5126 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 112/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4121 - accuracy: 0.5103 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 113/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4031 - accuracy: 0.5168 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 114/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4010 - accuracy: 0.5178 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 115/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4033 - accuracy: 0.5181 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 116/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4107 - accuracy: 0.5151 - val_loss: 1.4472 - val_accuracy: 0.4942
# Epoch 117/1000
# 1172/1172 [==============================] - 9s 7ms/step - loss: 1.4216 - accuracy: 0.5081 - val_loss: 1.4472 - val_accuracy: 0.4942

# %% [markdown]
# ## 8. Test your model

# %%
model.load_weights(model_name_fcn)
metrics = model.evaluate(X_test,Y_test_oh)

Ypred = model.predict(X_test).argmax(axis = 1)
wrong_indexes = np.where(Ypred != Y_test[:,0])[0]
print(wrong_indexes.size)

# Disaplying some samples from the development set
sample_indexes = np.random.choice(np.arange(wrong_indexes.shape[0], dtype = int),size = 30, replace = False)
plt.figure(figsize = (24,18))
for (ii,jj) in enumerate(sample_indexes):
    plt.subplot(5,6,ii+1)
    plt.imshow(X_test[wrong_indexes[jj]], cmap = "gray")
    plt.title("Label: %d, predicted: %d" %(Y_test[wrong_indexes[jj]],Ypred[wrong_indexes[jj]]))
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4476 - accuracy: 0.4905
# 5095

# %% [markdown]
# ## Convolutional Model
#
# ## 5. Define your  model, cost function, optimizer, learning rate

# %%
# Define your model here. Include accuracy in the metrics list when you compile it
# Experiment with different network architectures, learnig rates, dropout, etc.
def my_model_cnn(ishape = (32, 32, 3), k = 10, lr = 1e-4, drop=0.2):
  input_model = tf.keras.layers.Input(shape = ishape)
  layer1 = tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = "relu")(input_model)
  layer2 = tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = "relu")(layer1)  
  max_layer1 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(layer2)
  layer3 = tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = "relu")(max_layer1)
  layer4 = tf.keras.layers.Conv2D(filters =  64, kernel_size = (3, 3), activation =  "relu")(layer3) 
  max_layer2 = tf.keras.layers.MaxPool2D(pool_size = (2, 2))(layer4)
  flatten = tf.keras.layers.Flatten()(max_layer2)
  model_drop = tf.keras.layers.Dropout(rate=drop)(flatten)
  output = tf.keras.layers.Dense(units= 10, activation= "softmax")(model_drop)
  model = tf.keras.models.Model(inputs= input_model, outputs= output)
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='categorical_crossentropy', metrics = ["accuracy"])
  return model

# %%
model = my_model_cnn()
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                16010
# =================================================================
# Total params: 81,578
# Trainable params: 81,578
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6. Define your callbacks (save your model, patience, etc.)

# %%
model_name_cnn = "team_(team number)_FCN.h5"

# define your callbacks
# remember that you need to save the weights of your best model!

early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 20)

monitor = tf.keras.callbacks.ModelCheckpoint(model_name_cnn, monitor='val_loss',\
                                             verbose=0,save_best_only=True,\
                                             save_weights_only=True,\
                                             mode='min')
# Learning rate schedule
def scheduler(epoch, lr):
    if epoch%10 == 0:
        lr = lr/2
    return lr

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose = 0)

# %% [markdown]
# ## 7. Train your model

# %%
# train your model - decide for how many epochs
model.fit(X_train,Y_train_oh,batch_size = 32, epochs = 1000, \
          verbose = 1, callbacks= [early_stop, monitor, lr_schedule],validation_data=(X_val,Y_val_oh))
# Out:
# Epoch 1/1000
# 1172/1172 [==============================] - 132s 112ms/step - loss: 2.1065 - accuracy: 0.2192 - val_loss: 1.7268 - val_accuracy: 0.3770
# Epoch 2/1000
# 1172/1172 [==============================] - 130s 111ms/step - loss: 1.7270 - accuracy: 0.3753 - val_loss: 1.6025 - val_accuracy: 0.4195
# Epoch 3/1000
# 1172/1172 [==============================] - 131s 111ms/step - loss: 1.6249 - accuracy: 0.4069 - val_loss: 1.5369 - val_accuracy: 0.4386
# Epoch 4/1000
# 1172/1172 [==============================] - 131s 112ms/step - loss: 1.5481 - accuracy: 0.4370 - val_loss: 1.4646 - val_accuracy: 0.4742
# Epoch 5/1000
# 1172/1172 [==============================] - 130s 111ms/step - loss: 1.4978 - accuracy: 0.4611 - val_loss: 1.4282 - val_accuracy: 0.4899
# Epoch 6/1000
# 1172/1172 [==============================] - 131s 112ms/step - loss: 1.4498 - accuracy: 0.4781 - val_loss: 1.3771 - val_accuracy: 0.5072
# Epoch 7/1000
#  455/1172 [==========>...................] - ETA: 1:14 - loss: 1.4064 - accuracy: 0.4968

# %% [markdown]
# ## 8. Test your model

# %%
model.load_weights(model_name_cnn)
metrics = model.evaluate(X_test,Y_test_oh)

Ypred = model.predict(X_test).argmax(axis = 1)
wrong_indexes = np.where(Ypred != Y_test[:,0])[0]
print(wrong_indexes.size)

# Disaplying some samples from the development set
sample_indexes = np.random.choice(np.arange(wrong_indexes.shape[0], dtype = int),size = 30, replace = False)
plt.figure(figsize = (24,18))
for (ii,jj) in enumerate(sample_indexes):
    plt.subplot(5,6,ii+1)
    plt.imshow(X_test[wrong_indexes[jj]], cmap = "gray")
    plt.title("Label: %d, predicted: %d" %(Y_test[wrong_indexes[jj]],Ypred[wrong_indexes[jj]]))
plt.show()
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.8020 - accuracy: 0.3765
# 6235

# %% [markdown]
# ##  Team members participtaion
# (include the description of what each team member did and the consensus score for each team member)
#
# - **Bright Anorchie, Do Trong Anh, Alan Joseph, Aaron Joseph** helped design the model and write the code for fully connected model (**score 3**)
# - **Bright Anorchie, Do Trong Anh, Alan Joseph, Aaron Joseph** helped design helped to implement the data augmentation module (**score 3**)
